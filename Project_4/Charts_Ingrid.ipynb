# %%
# %matplotlib inline
import matplotlib.pyplot as plt   #Seaborn is base on Matpotlib so we still need this library
import pandas as pd
import seaborn as sns
import numpy as np

# %%
diamonds = pd.read_csv(r'C:\Users\Ingrid\Desktop\DAFT Nov 21\Projects\Project 4\diamonds_clean.csv')
diamonds.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z  \
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
#
#    clarity_new  color_new
# 0            1          5
# 1            2          5
# 2            4          5
# 3            3          1
# 4            1          0
# 5            5          0
# 6            6          1
# 7            2          2
# 8            3          5
# 9            4          2

# %% [markdown]
# # Pie

# %%
#Group by 'price'
pi = diamonds.groupby(['color'])['price'].mean()
pi
# Out:
# color
# D    3169.954096
# E    3076.752475
# F    3724.886397
# G    3999.135671
# H    4486.669196
# I    5091.874954
# J    5323.818020
# Name: price, dtype: float64

# %%
# Pie - color/price
diamonds.groupby(['color']).sum().plot(kind='pie', y='price', autopct='%1.0f%%', title='Price per color')
# Out:
# <AxesSubplot:title={'center':'Price per color'}, ylabel='price'>

# %% [markdown]
# # Boxplot

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.boxplot(y=diamonds.y, ax=ax[0])
sns.boxplot(y=diamonds.z, ax=ax[1])
plt.subplots_adjust(wspace=0.5)

# %%
#Boxplot for 'y' and 'y' - Outliers
diamonds.boxplot(column=['y','z'], color='black')
plt.title('Outliers for y and z')
# Out:
# Text(0.5, 1.0, 'Outliers for y and z')

# %%
# Seaborn - boxplot: Price per cut
sns.boxplot(data=diamonds, x='cut', y='price').set(title='Price per cut')
# Out:
# [Text(0.5, 1.0, 'Price per cut')]

# %% [markdown]
# # Bar

# %%
# Seaborn - barplot as horizontal: Price per color
sns.barplot(x = 'price', y = 'color', data = diamonds).set(title='Price per color')
# Out:
# [Text(0.5, 1.0, 'Price per color')]

# %% [markdown]
# # Scatterplot

# %%
# Seaborn - Scatter plot - columns 'carat' and 'price'
sns.scatterplot(x="clarity", y="price", hue="price", data=diamonds)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>

# %%
diamonds.plot.scatter(x="cut", y =["price"]) #just 1 variable
#plot is the wrapper of matplotlib in Pandas
# Out:
# <AxesSubplot:xlabel='cut', ylabel='[price]'>

# %%
#method catplot - looks like frequency
sns.catplot(x="cut", y="price", hue="cut", data=diamonds)

# %%
#method relplot
sns.relplot(x='clarity', y='price', hue="clarity", size="clarity", data=diamonds)

# %% [markdown]
# # Heatmap

# %%
#Heatmap
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %%
# Regplot
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)
# Out:
# C:\Users\Ingrid\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# # Scatter Matrix

# %%
# Scatter Matrix 
pd.plotting.scatter_matrix(diamonds)
# Out:
# array([[<AxesSubplot:xlabel='carat', ylabel='carat'>,
#         <AxesSubplot:xlabel='depth', ylabel='carat'>,
#         <AxesSubplot:xlabel='table', ylabel='carat'>,
#         <AxesSubplot:xlabel='price', ylabel='carat'>,
#         <AxesSubplot:xlabel='x', ylabel='carat'>,
#         <AxesSubplot:xlabel='y', ylabel='carat'>,
#         <AxesSubplot:xlabel='z', ylabel='carat'>,
#         <AxesSubplot:xlabel='clarity_new', ylabel='carat'>,
#         <AxesSubplot:xlabel='color_new', ylabel='carat'>],
#        [<AxesSubplot:xlabel='carat', ylabel='depth'>,
#         <AxesSubplot:xlabel='depth', ylabel='depth'>,
#         <AxesSubplot:xlabel='table', ylabel='depth'>,
#         <AxesSubplot:xlabel='price', ylabel='depth'>,
#         <AxesSubplot:xlabel='x', ylabel='depth'>,
#         <AxesSubplot:xlabel='y', ylabel='depth'>,
#         <AxesSubplot:xlabel='z', ylabel='depth'>,
#         <AxesSubplot:xlabel='clarity_new', ylabel='depth'>,
#         <AxesSubplot:xlabel='color_new', ylabel='depth'>],
#        [<AxesSubplot:xlabel='carat', ylabel='table'>,
#         <AxesSubplot:xlabel='depth', ylabel='table'>,
#         <AxesSubplot:xlabel='table', ylabel='table'>,
#         <AxesSubplot:xlabel='price', ylabel='table'>,
#         <AxesSubplot:xlabel='x', ylabel='table'>,
#         <AxesSubplot:xlabel='y', ylabel='table'>,
#         <AxesSubplot:xlabel='z', ylabel='table'>,
#         <AxesSubplot:xlabel='clarity_new', ylabel='table'>,
#         <AxesSubplot:xlabel='color_new', ylabel='table'>],
#        [<AxesSubplot:xlabel='carat', ylabel='price'>,
#         <AxesSubplot:xlabel='depth', ylabel='price'>,
#         <AxesSubplot:xlabel='table', ylabel='price'>,
#         <AxesSubplot:xlabel='price', ylabel='price'>,
#         <AxesSubplot:xlabel='x', ylabel='price'>,
#         <AxesSubplot:xlabel='y', ylabel='price'>,
#         <AxesSubplot:xlabel='z', ylabel='price'>,
#         <AxesSubplot:xlabel='clarity_new', ylabel='price'>,
#         <AxesSubplot:xlabel='color_new', ylabel='price'>],
#        [<AxesSubplot:xlabel='carat', ylabel='x'>,
#         <AxesSubplot:xlabel='depth', ylabel='x'>,
#         <AxesSubplot:xlabel='table', ylabel='x'>,
#         <AxesSubplot:xlabel='price', ylabel='x'>,
#         <AxesSubplot:xlabel='x', ylabel='x'>,
#         <AxesSubplot:xlabel='y', ylabel='x'>,
#         <AxesSubplot:xlabel='z', ylabel='x'>,
#         <AxesSubplot:xlabel='clarity_new', ylabel='x'>,
#         <AxesSubplot:xlabel='color_new', ylabel='x'>],
#        [<AxesSubplot:xlabel='carat', ylabel='y'>,
#         <AxesSubplot:xlabel='depth', ylabel='y'>,
#         <AxesSubplot:xlabel='table', ylabel='y'>,
#         <AxesSubplot:xlabel='price', ylabel='y'>,
#         <AxesSubplot:xlabel='x', ylabel='y'>,
#         <AxesSubplot:xlabel='y', ylabel='y'>,
#         <AxesSubplot:xlabel='z', ylabel='y'>,
#         <AxesSubplot:xlabel='clarity_new', ylabel='y'>,
#         <AxesSubplot:xlabel='color_new', ylabel='y'>],
#        [<AxesSubplot:xlabel='carat', ylabel='z'>,
#         <AxesSubplot:xlabel='depth', ylabel='z'>,
#         <AxesSubplot:xlabel='table', ylabel='z'>,
#         <AxesSubplot:xlabel='price', ylabel='z'>,
#         <AxesSubplot:xlabel='x', ylabel='z'>,
#         <AxesSubplot:xlabel='y', ylabel='z'>,
#         <AxesSubplot:xlabel='z', ylabel='z'>,
#         <AxesSubplot:xlabel='clarity_new', ylabel='z'>,
#         <AxesSubplot:xlabel='color_new', ylabel='z'>],
#        [<AxesSubplot:xlabel='carat', ylabel='clarity_new'>,
#         <AxesSubplot:xlabel='depth', ylabel='clarity_new'>,
#         <AxesSubplot:xlabel='table', ylabel='clarity_new'>,
#         <AxesSubplot:xlabel='price', ylabel='clarity_new'>,
#         <AxesSubplot:xlabel='x', ylabel='clarity_new'>,
#         <AxesSubplot:xlabel='y', ylabel='clarity_new'>,
#         <AxesSubplot:xlabel='z', ylabel='clarity_new'>,
#         <AxesSubplot:xlabel='clarity_new', ylabel='clarity_new'>,
#         <AxesSubplot:xlabel='color_new', ylabel='clarity_new'>],
#        [<AxesSubplot:xlabel='carat', ylabel='color_new'>,
#         <AxesSubplot:xlabel='depth', ylabel='color_new'>,
#         <AxesSubplot:xlabel='table', ylabel='color_new'>,
#         <AxesSubplot:xlabel='price', ylabel='color_new'>,
#         <AxesSubplot:xlabel='x', ylabel='color_new'>,
#         <AxesSubplot:xlabel='y', ylabel='color_new'>,
#         <AxesSubplot:xlabel='z', ylabel='color_new'>,
#         <AxesSubplot:xlabel='clarity_new', ylabel='color_new'>,
#         <AxesSubplot:xlabel='color_new', ylabel='color_new'>]],
#       dtype=object)

# %%
#sort the DF, inplace True to modify the data
#diamonds.sort_values(by=["price", "color", "carat", "depth", "clarity"], inplace=True) 

#diamonds.plot(x="price", y =["color", "carat", "depth", "clarity"])
